# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import math as math
import random
from faker.providers.person.en import Provider

# %%
file = 'realdata.tsv'
poaFile = 'poamatches.tsv' #optional
out_file = 'generated_data.tsv'

# %%
company_type_dict = {
'acxiom':'broker',
'ancestry' :'consumer',
'beenverified': 'broker',
'clubhouse' : 'social',
'infinitemediaconcepts':'broker',
'intel': 'broker',
'mcdonalds' :'consumer',
'mediaocean': 'broker',
'mylife': 'broker',
'neustar' : 'broker',
'oracle' : 'broker',
'quora' : 'social',
'target' : 'consumer',
'tesla' : 'consumer',
'thomsonreuters':'broker',
'tmobile' : 'telco',
'twitter' : 'social',  
'uber': 'consumer',
'walgreens':'consumer',
'walmart':	'consumer',
'xfinity':	'telco',    
}

# %%
companies = list(company_type_dict.keys())
cols = ['onboardID', 'company1', 'company2'] + companies
data = {}

# %%
numPeople = 200 # number of rows to generate

# %%
# Generate names
names = np.random.choice(getattr(Provider, "first_names"), size=numPeople)
data["name"] = names

# %%
# generate onboardIDs
#oids = np.random.randint(15, high=1000, size=numPeople)
oids = random.sample(range(10,numPeople*10), numPeople) #generate random IDs
data["onboardID"] = oids

# %%
# initialize empty match matrix
for company in companies:
    data[company] = [0] * numPeople

# %%
data = pd.DataFrame.from_dict(data)
data = data.set_index('onboardID')
data.head()
# Out:
#            acxiom  ancestry  beenverified  clubhouse  infinitemediaconcepts  \
# onboardID
# 1615            0         0             0          0                      0
# 337             0         0             0          0                      0
# 1887            0         0             0          0                      0
# 12              0         0             0          0                      0
# 965             0         0             0          0                      0
#
#            intel  mcdonalds  mediaocean  mylife     name   ...     quora  \
# onboardID                                                  ...
# 1615           0          0           0       0    Wanda   ...         0
# 337            0          0           0       0  Shakira   ...         0
# 1887           0          0           0       0  Ardelia   ...         0
# 12             0          0           0       0    Devyn   ...         0
# 965            0          0           0       0    Javen   ...         0
#
#            target  tesla  thomsonreuters  tmobile  twitter  uber  walgreens  \
# onboardID
# 1615            0      0               0        0        0     0          0
# 337             0      0               0        0        0     0          0
# 1887            0      0               0        0        0     0          0
# 12              0      0               0        0        0     0          0
# 965             0      0               0        0        0     0          0
#
#            walmart  xfinity
# onboardID
# 1615             0        0
# 337              0        0
# 1887             0        0
# 12               0        0
# 965              0        0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Generate account pairings
#  generate account pairings. This is the tricky part.
#  Some companies are rare (few people have an account with Tesla, e.g.).
#  This fact is important for testing, so we need to simulate something close.

# %%
# First let's see which companies are rare from the real data we already have.
people_sample = pd.read_csv(file, delimiter="\t", index_col='onboardID')
people_sample.sample(3)
# Out:
#            acxiom  ancestry  beenverified  clubhouse  infinitemediaconcepts  \
# onboardID
# 424             0         0             0          1                      0
# 146             0         0             0          0                      0
# 683             0         0             0          0                      0
#
#            intel  mcdonalds  mediaocean  mylife       name   ...     quora  \
# onboardID                                                    ...
# 424            0          0           0       0    Jeannie   ...         0
# 146            0          0           0       0     Bobbie   ...         1
# 683            0          0           0       0  Bridgette   ...         0
#
#            target  tesla  thomsonreuters  tmobile  twitter  uber  walgreens  \
# onboardID
# 424             0      0               1        0        1     1          1
# 146             0      1               0        1        1     1          1
# 683             1      0               0        0        1     0          1
#
#            walmart  xfinity
# onboardID
# 424              0        0
# 146              0        0
# 683              1        1
#
# [3 rows x 22 columns]

# %%
# Second, find the account distribution of companies.
rare_companies = people_sample[companies].sum().sort_values()
rare_companies = rare_companies/len(people_sample.index)
rare_companies
# Out:
# beenverified             0.01
# neustar                  0.01
# mediaocean               0.01
# mylife                   0.01
# infinitemediaconcepts    0.02
# tesla                    0.04
# acxiom                   0.05
# thomsonreuters           0.06
# intel                    0.08
# xfinity                  0.12
# clubhouse                0.12
# oracle                   0.13
# ancestry                 0.14
# mcdonalds                0.15
# quora                    0.22
# walmart                  0.28
# target                   0.29
# walgreens                0.32
# tmobile                  0.38
# uber                     0.38
# twitter                  0.48
# dtype: float64

# %%
# Now we can build a pool of companies that we can select for ppl
company_pool = ((rare_companies * numPeople + 1) // 1).to_dict()
l = []
for company, count in company_pool.items():
 l.extend([company] * int(count))
random.shuffle(l)
company_pool = l * 2

# %%
# Randomly assign a handful of accounts to people
random.shuffle(company_pool)

for person in oids:
    n_accounts = random.randint(1,6) # pick how many new accounts
    for i in range(n_accounts):
        company = company_pool.pop() 
        data.at[person, company] = 1 #assign the new account
    random.shuffle(company_pool)

# %%
# check out the distribution of the new accounts
display("number of people", numPeople)
data[companies].sum().sort_values()
# Out:
# 'number of people'
# 200
# beenverified               5
# mylife                     5
# neustar                    7
# mediaocean                 7
# infinitemediaconcepts     10
# tesla                     17
# acxiom                    24
# thomsonreuters            29
# intel                     33
# xfinity                   41
# clubhouse                 47
# oracle                    47
# ancestry                  58
# mcdonalds                 59
# quora                     68
# target                    90
# walmart                   96
# walgreens                105
# uber                     111
# tmobile                  112
# twitter                  124
# dtype: int64

# %%
data.head()
# Out:
#            acxiom  ancestry  beenverified  clubhouse  infinitemediaconcepts  \
# onboardID
# 1615            0         0             0          0                      0
# 337             0         0             0          0                      0
# 1887            0         0             0          0                      0
# 12              0         0             0          0                      0
# 965             0         0             0          0                      0
#
#            intel  mcdonalds  mediaocean  mylife     name   ...     quora  \
# onboardID                                                  ...
# 1615           0          1           0       0    Wanda   ...         0
# 337            0          1           0       0  Shakira   ...         0
# 1887           0          0           0       0  Ardelia   ...         0
# 12             0          0           0       0    Devyn   ...         0
# 965            0          1           0       0    Javen   ...         1
#
#            target  tesla  thomsonreuters  tmobile  twitter  uber  walgreens  \
# onboardID
# 1615            0      0               0        1        1     1          1
# 337             1      0               1        0        0     0          0
# 1887            0      1               1        1        1     1          1
# 12              0      1               0        1        0     1          0
# 965             1      0               0        0        0     1          0
#
#            walmart  xfinity
# onboardID
# 1615             0        0
# 337              0        0
# 1887             1        1
# 12               1        0
# 965              0        0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Put the matches in a handy format for exporting

# %%
data.to_csv(out_file, sep="\t")
